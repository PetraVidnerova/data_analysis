# %%
import pandas as pd

# %% [markdown]
# #  Read data files and concat them

# %%
students_mat = pd.read_csv('student-mat.csv')
students_por = pd.read_csv('student-por.csv')
assert all(students_mat.columns == students_por.columns)

students = pd.concat([students_mat, students_por])
students.reset_index(inplace=True, drop=True)

print(students.shape)
students.head()
# Out:
# (1044, 33)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# #  Delete duplicate students
#
# There are students who attended both classes.

# %%
id_columns = list(students.columns) 
id_columns.remove('absences')
id_columns.remove('G1')
id_columns.remove('G2')
id_columns.remove('G3')

students[students.duplicated(subset=id_columns, keep=False)]
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 6        GP   M   16       U     LE3       T     2     2     other     other
# 7        GP   F   17       U     GT3       A     4     4     other   teacher
# 11       GP   F   15       U     GT3       T     2     1  services     other
# 14       GP   M   15       U     GT3       A     2     2     other     other
# 15       GP   F   16       U     GT3       T     4     4    health     other
# 17       GP   F   16       U     GT3       T     3     3     other     other
# 20       GP   M   15       U     GT3       T     4     3   teacher     other
# 21       GP   M   15       U     GT3       T     4     4    health    health
# 22       GP   M   16       U     LE3       T     4     2   teacher     other
# ...

# %%
students.drop_duplicates(subset=id_columns, inplace=True)
students.shape
# Out:
# (880, 33)

# %%
students.reset_index(inplace=True, drop=True)
students.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 875     MS   F   18       R     GT3       T     2     2  at_home     other
# 876     MS   F   17       U     GT3       T     4     3  teacher     other
# 877     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 878     MS   F   18       U     LE3       T     3     1  teacher  services
# 879     MS   F   18       U     GT3       T     1     1    other     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 875 ...      5        3      3     1     3      4        0  14  17  15
# 876 ...      5        5      4     1     1      1        0   6   9  11
# 877 ...      4        4      3     2     2      5        4   7   9  10
# 878 ...      4        3      4     1     1      1        4  15  15  16
# 879 ...      1        1      1     1     1      5        6  11  12   9
#
# [5 rows x 33 columns]

# %% [markdown]
# # Get rid of unwanted columns

# %%
students = students.drop("school", axis=1)
students = students.drop("guardian", axis=1)
students = students.drop("reason", axis=1)
students = students.drop(["failures", "schoolsup", "famsup"], axis=1)
students.head()
# Out:
#   sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  traveltime  \
# 0   F   18       U     GT3       A     4     4  at_home   teacher           2
# 1   F   17       U     GT3       T     1     1  at_home     other           1
# 2   F   15       U     LE3       T     1     1  at_home     other           1
# 3   F   15       U     GT3       T     4     2   health  services           1
# 4   F   16       U     GT3       T     3     3    other     other           1
#
#   ...  famrel freetime goout Dalc Walc health absences  G1  G2  G3
# 0 ...       4        3     4    1    1      3        6   5   6   6
# 1 ...       5        3     3    1    1      3        4   5   5   6
# 2 ...       4        3     2    2    3      3       10   7   8  10
# 3 ...       3        2     2    1    1      5        2  15  14  15
# 4 ...       4        3     2    1    2      5        4   6  10  10
#
# [5 rows x 27 columns]

# %% [markdown]
# #  Add average alcohol consumption

# %%
students['Aalc'] = (5*students['Dalc'] + 2*students['Walc'])/7
print(students.shape)
students.head()
# Out:
# (880, 28)
#   sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  traveltime  \
# 0   F   18       U     GT3       A     4     4  at_home   teacher           2
# 1   F   17       U     GT3       T     1     1  at_home     other           1
# 2   F   15       U     LE3       T     1     1  at_home     other           1
# 3   F   15       U     GT3       T     4     2   health  services           1
# 4   F   16       U     GT3       T     3     3    other     other           1
#
#      ...     freetime goout Dalc Walc health absences  G1  G2  G3      Aalc
# 0    ...            3     4    1    1      3        6   5   6   6  1.000000
# 1    ...            3     3    1    1      3        4   5   5   6  1.000000
# 2    ...            3     2    2    3      3       10   7   8  10  2.285714
# 3    ...            2     2    1    1      5        2  15  14  15  1.000000
# 4    ...            3     2    1    2      5        4   6  10  10  1.285714
#
# [5 rows x 28 columns]

# %% [markdown]
# # Get rid of yes/no values

# %%
students.replace('yes', True, inplace=True)
students.replace('no', False, inplace=True)

# %%
students[['internet', 'romantic']].head()
# Out:
#    internet  romantic
# 0     False     False
# 1      True     False
# 2      True     False
# 3      True      True
# 4     False     False

# %% [markdown]
# # Save to file

# %%
students.to_csv("students.csv")
